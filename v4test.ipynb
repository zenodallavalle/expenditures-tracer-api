# %%
import requests
import json

BASE_URL = "http://localhost:8000/v4/"
session = requests.Session()
session.headers.update(
    {"Authorization": "Token b0384c59070df7c4c7fca94528e11a7337e1b3d4"}
)
import pandas as pd

# %%
r = session.get(BASE_URL + "dbs/1/", params={
    "month_list_gte": "01-2021",
    "month_list_lte": "12-2021",
})
try:
    df = pd.DataFrame(r.json()['months_list'])
except Exception:
    print(r.text)

# %%
df
# Out:
#       month  is_working  income  current_money  warn  expenditure  \
# 0   12-2021       False  1750.0         3298.0  None       -640.0
# 1   11-2021       False  2002.0         2188.0  None      -3301.0
# 2   10-2021       False   950.0         3487.0  None      -1150.0
# 3   09-2021       False   350.0         3687.0  None      -1024.0
# 4   08-2021       False   500.0         4361.0  None       -693.0
# 5   07-2021       False  1850.0         4554.0  None       -826.0
# 6   06-2021       False   350.0         3530.0  None       -730.0
# 7   05-2021       False  1750.0         3910.0  None       -568.0
# 8   04-2021       False  1080.0         2728.0  None       -390.0
# 9   03-2021       False   405.0         2038.0  None       -335.0
# 10  02-2021       False   380.0         1968.0  None       -977.0
# 11  01-2021       False  1005.0         2565.0  None       -411.0
#
#     previous_month_actual_money
# 0                        2188.0
# 1                        3487.0
# ...
